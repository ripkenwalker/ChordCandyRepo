# %%
numToName = {'C': 
                {'C Major': {
                    485255: 'C Major Root Position', 
                    525560: 'C Major 1st Inversion', 
                    556062: 'C Major 2nd Inversion'},
                
                'C Minor': {
                    485155: 'C Minor Root Postition',
                    515560: 'C Minor 1st Inversion',
                    556063: 'C Minor 2nd Inversion'},

                'C Diminished': {
                    485154: 'C Diminished Root Position',
                    515460: 'C Diminished 1st Inversion',
                    546063: 'C Diminished 2nd Inversion'},

                'C Augmented': {
                    485256: 'C Augmented Root Position',
                    525660: 'C Augmented 1st Inversion',
                    566063: 'C Augmented 2nd Inversion'}
                },

            'C#/Db': 
                {'C#/Db Major': {
                    495356: 'C#/Db Major Root Position', 
                    535661: 'C#/Db Major 1st Inversion', 
                    566165: 'C#/Db Major 2nd Inversion'},
                
                'C#/Db Minor': {
                    495256: 'C#/Db Minor Root Postition',
                    525661: 'C#/Db Minor 1st Inversion',
                    566164: 'C#/Db Minor 2nd Inversion'},

                'C#/Db Diminished': {
                    495255: 'C#/Db Diminished Root Position',
                    525561: 'C#/Db Diminished 1st Inversion',
                    556164: 'C#/Db Diminished 2nd Inversion'},

                'C#/Db Augmented': {
                    495357: 'C#/Db Augmented Root Position',
                    535761: 'C#/Db Augmented 1st Inversion',
                    576165: 'C#/Db Augmented 2nd Inversion'}
                },

            'D': 
                {'D Major': {
                    505457: 'D Major Root Position', 
                    545762: 'D Major 1st Inversion', 
                    576266: 'D Major 2nd Inversion'},
                
                'D Minor': {
                    505357: 'D Minor Root Postition',
                    535762: 'D Minor 1st Inversion',
                    576265: 'D Minor 2nd Inversion'},

                'D Diminished': {
                    505356: 'D Diminished Root Position',
                    535662: 'D Diminished 1st Inversion',
                    566265: 'D Diminished 2nd Inversion'},

                'D Augmented': {
                    505458: 'D Augmented Root Position',
                    545862: 'D Augmented 1st Inversion',
                    586266: 'D Augmented 2nd Inversion'}
                },

            'D#/Db': 
                {'D#/Db Major': {
                    515558: 'D#/Db Major Root Position', 
                    555863: 'D#/Db Major 1st Inversion', 
                    586367: 'D#/Db Major 2nd Inversion'},
                
                'D#/Db Minor': {
                    515458: 'D#/Db Minor Root Postition',
                    545863: 'D#/Db Minor 1st Inversion',
                    586366: 'D#/Db Minor 2nd Inversion'},

                'D#/Db Diminished': {
                    515457: 'D#/Db Diminished Root Position',
                    545763: 'D#/Db Diminished 1st Inversion',
                    545766: 'D#/Db Diminished 2nd Inversion'},

                'D#/Db Augmented': {
                    515559: 'D#/Db Augmented Root Position',
                    555963: 'D#/Db Augmented 1st Inversion',
                    596367: 'D#/Db Augmented 2nd Inversion'}
                },

            'E': 
                {'E Major': {
                    525659: 'E Major Root Position', 
                    565964: 'E Major 1st Inversion', 
                    596468: 'E Major 2nd Inversion'},
                
                'E Minor': {
                    525559: 'E Minor Root Postition',
                    555964: 'E Minor 1st Inversion',
                    596467: 'E Minor 2nd Inversion'},

                'E Diminished': {
                    525558: 'E Diminished Root Position',
                    555864: 'E Diminished 1st Inversion',
                    586467: 'E Diminished 2nd Inversion'},

                'E Augmented': {
                    525660: 'E Augmented Root Position',
                    566064: 'E Augmented 1st Inversion',
                    485256: 'E Augmented 2nd Inversion'}
                },

            'F': 
                {'F Major': {
                    535760: 'F Major Root Position', 
                    576065: 'F Major 1st Inversion', 
                    485357: 'F Major 2nd Inversion'},
                
                'F Minor': {
                    535660: 'F Minor Root Postition',
                    566065: 'F Minor 1st Inversion',
                    485356: 'F Minor 2nd Inversion'},

                'F Diminished': {
                    535659: 'F Diminished Root Position',
                    565965: 'F Diminished 1st Inversion',
                    596568: 'F Diminished 2nd Inversion'},

                'F Augmented': {
                    535761: 'F Augmented Root Position',
                    576165: 'F Augmented 1st Inversion',
                    495357: 'F Augmented 2nd Inversion'}
                },

            'F#/Gb': 
                {'F#/Gb Major': {
                    545861: 'F#/Gb Major Root Position', 
                    586166: 'F#/Gb Major 1st Inversion', 
                    495458: 'F#/Gb Major 2nd Inversion'},
                
                'F#/Gb Minor': {
                    545761: 'F#/Gb Minor Root Postition',
                    576166: 'F#/Gb Minor 1st Inversion',
                    495457: 'F#/Gb Minor 2nd Inversion'},

                'F#/Gb Diminished': {
                    545760: 'F#/Gb Diminished Root Position',
                    576066: 'F#/Gb Diminished 1st Inversion',
                    485760: 'F#/Gb Diminished 2nd Inversion'},

                'F#/Gb Augmented': {
                    545862: 'F#/Gb Augmented Root Position',
                    586266: 'F#/Gb Augmented 1st Inversion',
                    505458: 'F#/Gb Augmented 2nd Inversion'}
                },

            'G': 
                {'G Major': {
                    555962: 'G Major Root Position', 
                    596267: 'G Major 1st Inversion', 
                    505559: 'G Major 2nd Inversion'},
                
                'G Minor': {
                    555862: 'G Minor Root Postition',
                    586267: 'G Minor 1st Inversion',
                    505558: 'G Minor 2nd Inversion'},

                'G Diminished': {
                    555861: 'G Diminished Root Position',
                    586167: 'G Diminished 1st Inversion',
                    495558: 'G Diminished 2nd Inversion'},

                'G Augmented': {
                    555963: 'G Augmented Root Position',
                    596367: 'G Augmented 1st Inversion',
                    515559: 'G Augmented 2nd Inversion'}
                },

            'G#/Ab': 
                {'G#/Ab Major': {
                    566063: 'G#/Ab Major Root Position', 
                    485156: 'G#/Ab Major 1st Inversion', 
                    515660: 'G#/Ab Major 2nd Inversion'},
                
                'G#/Ab Minor': {
                    565963: 'G#/Ab Minor Root Postition',
                    596268: 'G#/Ab Minor 1st Inversion',
                    505659: 'G#/Ab Minor 2nd Inversion'},

                'G#/Ab Diminished': {
                    565962: 'G#/Ab Diminished Root Position',
                    596268: 'G#/Ab Diminished 1st Inversion',
                    505659: 'G#/Ab Diminished 2nd Inversion'},

                'G#/Ab Augmented': {
                    566064: 'G#/Ab Augmented Root Position',
                    485256: 'G#/Ab Augmented 1st Inversion',
                    525660: 'G#/Ab Augmented 2nd Inversion'}
                },

            'A': 
                {'A Major': {
                    576164: 'A Major Root Position', 
                    495257: 'A Major 1st Inversion', 
                    525761: 'A Major 2nd Inversion'},
                
                'A Minor': {
                    576064: 'A Minor Root Postition',
                    485257: 'A Minor 1st Inversion',
                    525760: 'A Minor 2nd Inversion'},

                'A Diminished': {
                    576063: 'A Diminished Root Position',
                    485157: 'A Diminished 1st Inversion',
                    515760: 'A Diminished 2nd Inversion'},

                'A Augmented': {
                    576165: 'A Augmented Root Position',
                    495357: 'A Augmented 1st Inversion',
                    535761: 'A Augmented 2nd Inversion'}
                },

            'A#/Bb': 
                {'A#/Bb Major': {
                    586265: 'A#/Bb Major Root Position', 
                    505358: 'A#/Bb Major 1st Inversion', 
                    535862: 'A#/Bb Major 2nd Inversion'},
                
                'A#/Bb Minor': {
                    586165: 'A#/Bb Minor Root Postition',
                    495358: 'A#/Bb Minor 1st Inversion',
                    525861: 'A#/Bb Minor 2nd Inversion'},

                'A#/Bb Diminished': {
                    586164: 'A#/Bb Diminished Root Position',
                    495258: 'A#/Bb Diminished 1st Inversion',
                    525861: 'A#/Bb Diminished 2nd Inversion'},

                'A#/Bb Augmented': {
                    586266: 'A#/Bb Augmented Root Position',
                    505458: 'A#/Bb Augmented 1st Inversion',
                    545862: 'A#/Bb Augmented 2nd Inversion'}
                },

            'B': 
                {'B Major': {
                    596366: 'B Major Root Position', 
                    515459: 'B Major 1st Inversion', 
                    545963: 'B Major 2nd Inversion'},
                
                'B Minor': {
                    596266: 'B Minor Root Postition',
                    505459: 'B Minor 1st Inversion',
                    545962: 'B Minor 2nd Inversion'},

                'B Diminished': {
                    596265: 'B Diminished Root Position',
                    505359: 'B Diminished 1st Inversion',
                    535962: 'B Diminished 2nd Inversion'},

                'B Augmented': {
                    596367: 'B Augmented Root Position',
                    515559: 'B Augmented 1st Inversion',
                    559963: 'B Augmented 2nd Inversion'}
                }
}

# %%
nameToNum = {'C': 
                {'C Major': {
                    'C Major Root Position': 606467, 
                    'C Major 1st Inversion': 676064, 
                    'C Major 2nd Inversion': 66760},
                
                'C Minor': {
                    'C Minor Root Postition': 606367,
                    'C Minor 1st Inversion': 676063,
                    'C Minor 2nd Inversion': 636760},

                'C Diminished': {
                    'C Diminished Root Position': 606366,
                    'C Diminished 1st Inversion': 666063,
                    'C Diminished 2nd Inversion': 636660},

                'C Augmented': {
                    'C Augmented Root Position': 606468,
                    'C Augmented 1st Inversion': 686064,
                    'C Augmented 2nd Inversion': 646860}
                },
            
            'C#/Db': 
                {'C#/Db Major': {
                    'C#/Db Major Root Position': 616568, 
                    'C#/Db Major 1st Inversion': 686165, 
                    'C#/Db Major 2nd Inversion': 656861},
                
                'C#/Db Minor': {
                    'C#/Db Minor Root Postition': 616468,
                    'C#/Db Minor 1st Inversion': 686164,
                    'C#/Db Minor 2nd Inversion': 646861},

                'C#/Db Diminished': {
                    'C#/Db Diminished Root Position': ,
                    'C#/Db Diminished 1st Inversion': ,
                    'C#/Db Diminished 2nd Inversion': },

                'C#/Db Augmented': {
                    'C#/Db Augmented Root Position': ,
                    'C#/Db Augmented 1st Inversion': ,
                    'C#/Db Augmented 2nd Inversion': }
                },

            'D': 
                {'D Major': {
                    'D Major Root Position': , 
                    'D Major 1st Inversion': , 
                    'D Major 2nd Inversion': },
                
                'D Minor': {
                    'D Minor Root Postition': ,
                    'D Minor 1st Inversion': ,
                    'D Minor 2nd Inversion': },

                'D Diminished': {
                    'D Diminished Root Position': ,
                    'D Diminished 1st Inversion': ,
                    'D Diminished 2nd Inversion': },

                'D Augmented': {
                    'D Augmented Root Position': ,
                    'D Augmented 1st Inversion': ,
                    'D Augmented 2nd Inversion': }
                },

            'D#/Eb': 
                {'D#/Eb Major': {
                    'D#/Eb Major Root Position': , 
                    'D#/Eb Major 1st Inversion': , 
                    'D#/Eb Major 2nd Inversion': },
                
                'D#/Eb Minor': {
                    'D#/Eb Minor Root Postition': ,
                    'D#/Eb Minor 1st Inversion': ,
                    'D#/Eb Minor 2nd Inversion': },

                'D#/Eb Diminished': {
                    'D#/Eb Diminished Root Position': ,
                    'D#/Eb Diminished 1st Inversion': ,
                    'D#/Eb Diminished 2nd Inversion': },

                'D#/Eb Augmented': {
                    'D#/Eb Augmented Root Position': ,
                    'D#/Eb Augmented 1st Inversion': ,
                    'D#/Eb Augmented 2nd Inversion': }
                },
            
            'E': 
                {'E Major': {
                    'E Major Root Position': , 
                    'E Major 1st Inversion': , 
                    'E Major 2nd Inversion': },
                
                'E Minor': {
                    'E Minor Root Postition': ,
                    'E Minor 1st Inversion': ,
                    'E Minor 2nd Inversion': },

                'E Diminished': {
                    'E Diminished Root Position': ,
                    'E Diminished 1st Inversion': ,
                    'E Diminished 2nd Inversion': },

                'E Augmented': {
                    'E Augmented Root Position': ,
                    'E Augmented 1st Inversion': ,
                    'E Augmented 2nd Inversion': }
                },
            
            'F': 
                {'F Major': {
                    'F Major Root Position': , 
                    'F Major 1st Inversion': , 
                    'F Major 2nd Inversion': },
                
                'F Minor': {
                    'F Minor Root Postition': ,
                    'F Minor 1st Inversion': ,
                    'F Minor 2nd Inversion': },

                'F Diminished': {
                    'F Diminished Root Position': ,
                    'F Diminished 1st Inversion': ,
                    'F Diminished 2nd Inversion': },

                'F Augmented': {
                    'F Augmented Root Position': ,
                    'F Augmented 1st Inversion': ,
                    'F Augmented 2nd Inversion': }
                },

            'F#/Gb': 
                {'F#/Gb Major': {
                    'F#/Gb Major Root Position': , 
                    'F#/Gb Major 1st Inversion': , 
                    'F#/Gb Major 2nd Inversion': },
                
                'F#/Gb Minor': {
                    'F#/Gb Minor Root Postition': ,
                    'F#/Gb Minor 1st Inversion': ,
                    'F#/Gb Minor 2nd Inversion': },

                'F#/Gb Diminished': {
                    'F#/Gb Diminished Root Position': ,
                    'F#/Gb Diminished 1st Inversion': ,
                    'F#/Gb Diminished 2nd Inversion': },

                'F#/Gb Augmented': {
                    'F#/Gb Augmented Root Position': ,
                    'F#/Gb Augmented 1st Inversion': ,
                    'F#/Gb Augmented 2nd Inversion': }
                },

            'G': 
                {'G Major': {
                    'G Major Root Position': , 
                    'G Major 1st Inversion': , 
                    'G Major 2nd Inversion': },
                
                'G Minor': {
                    'G Minor Root Postition': ,
                    'G Minor 1st Inversion': ,
                    'G Minor 2nd Inversion': },

                'G Diminished': {
                    'G Diminished Root Position': ,
                    'G Diminished 1st Inversion': ,
                    'G Diminished 2nd Inversion': },

                'G Augmented': {
                    'G Augmented Root Position': ,
                    'G Augmented 1st Inversion': ,
                    'G Augmented 2nd Inversion': }
                },
                
            'G#/Ab': 
                {'G#/Ab Major': {
                    'G#/Ab Major Root Position': , 
                    'G#/Ab Major 1st Inversion': , 
                    'G#/Ab Major 2nd Inversion': },
                
                'G#/Ab Minor': {
                    'G#/Ab Minor Root Postition': ,
                    'G#/Ab Minor 1st Inversion': ,
                    'G#/Ab Minor 2nd Inversion': },

                'G#/Ab Diminished': {
                    'G#/Ab Diminished Root Position': ,
                    'G#/Ab Diminished 1st Inversion': ,
                    'G#/Ab Diminished 2nd Inversion': },

                'G#/Ab Augmented': {
                    'G#/Ab Augmented Root Position': ,
                    'G#/Ab Augmented 1st Inversion': ,
                    'G#/Ab Augmented 2nd Inversion': }
                },
            
            'A': 
                {'A Major': {
                    'A Major Root Position': , 
                    'A Major 1st Inversion': , 
                    'A Major 2nd Inversion': },
                
                'A Minor': {
                    'A Minor Root Postition': ,
                    'A Minor 1st Inversion': ,
                    'A Minor 2nd Inversion': },

                'A Diminished': {
                    'A Diminished Root Position': ,
                    'A Diminished 1st Inversion': ,
                    'A Diminished 2nd Inversion': },

                'A Augmented': {
                    'A Augmented Root Position': ,
                    'A Augmented 1st Inversion': ,
                    'A Augmented 2nd Inversion': }
                },

            'A#/Bb': 
                {'A#/Bb Major': {
                    'A#/Bb Major Root Position': , 
                    'A#/Bb Major 1st Inversion': , 
                    'A#/Bb Major 2nd Inversion': },
                
                'A#/Bb Minor': {
                    'A#/Bb Minor Root Postition': ,
                    'A#/Bb Minor 1st Inversion': ,
                    'A#/Bb Minor 2nd Inversion': },

                'A#/Bb Diminished': {
                    'A#/Bb Diminished Root Position': ,
                    'A#/Bb Diminished 1st Inversion': ,
                    'A#/Bb Diminished 2nd Inversion': },

                'A#/Bb Augmented': {
                    'A#/Bb Augmented Root Position': ,
                    'A#/Bb Augmented 1st Inversion': ,
                    'A#/Bb Augmented 2nd Inversion': }
                },

            'B': 
                {'B Major': {
                    'B Major Root Position': , 
                    'B Major 1st Inversion': , 
                    'B Major 2nd Inversion': },
                
                'B Minor': {
                    'B Minor Root Postition': ,
                    'B Minor 1st Inversion': ,
                    'B Minor 2nd Inversion': },

                'B Diminished': {
                    'B Diminished Root Position': ,
                    'B Diminished 1st Inversion': ,
                    'B Diminished 2nd Inversion': },

                'B Augmented': {
                    'B Augmented Root Position': ,
                    'B Augmented 1st Inversion': ,
                    'B Augmented 2nd Inversion': }
                }
        }
