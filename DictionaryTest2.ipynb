# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import math
from nested_lookup import nested_lookup

# %%
nameToNum = {'C': 
                {'C Major': {
                    'C Major Root Position': 485255, 
                    'C Major 1st Inversion': 525560, 
                    'C Major 2nd Inversion': 556062},
                
                'C Minor': {
                    'C Minor Root Position': 485155,
                    'C Minor 1st Inversion': 515560,
                    'C Minor 2nd Inversion': 556063},

                'C Diminished': {
                    'C Diminished Root Position': 485154,
                    'C Diminished 1st Inversion': 515460,
                    'C Diminished 2nd Inversion': 546063},

                'C Augmented': {
                    'C Augmented Root Position': 485256,
                    'C Augmented 1st Inversion': 525660,
                    'C Augmented 2nd Inversion': 566063}
                },
            
            'C#/Db': 
                {'C#/Db Major': {
                    'C#/Db Major Root Position': 495356, 
                    'C#/Db Major 1st Inversion': 535661, 
                    'C#/Db Major 2nd Inversion': 566165},
                
                'C#/Db Minor': {
                    'C#/Db Minor Root Position': 495256,
                    'C#/Db Minor 1st Inversion': 525661,
                    'C#/Db Minor 2nd Inversion': 566164},

                'C#/Db Diminished': {
                    'C#/Db Diminished Root Position': 495255,
                    'C#/Db Diminished 1st Inversion': 525561,
                    'C#/Db Diminished 2nd Inversion': 556164},

                'C#/Db Augmented': {
                    'C#/Db Augmented Root Position': 495357,
                    'C#/Db Augmented 1st Inversion': 535761,
                    'C#/Db Augmented 2nd Inversion': 576165}
                },

            'D': 
                {'D Major': {
                    'D Major Root Position': 505457, 
                    'D Major 1st Inversion': 545762, 
                    'D Major 2nd Inversion': 576266},
                
                'D Minor': {
                    'D Minor Root Position': 505357,
                    'D Minor 1st Inversion': 535762,
                    'D Minor 2nd Inversion': 576265},

                'D Diminished': {
                    'D Diminished Root Position': 505356,
                    'D Diminished 1st Inversion': 535662,
                    'D Diminished 2nd Inversion': 566265},

                'D Augmented': {
                    'D Augmented Root Position': 505458,
                    'D Augmented 1st Inversion': 545862,
                    'D Augmented 2nd Inversion': 586266}
                },

            'D#/Eb': 
                {'D#/Eb Major': {
                    'D#/Eb Major Root Position': 515558, 
                    'D#/Eb Major 1st Inversion': 555863, 
                    'D#/Eb Major 2nd Inversion': 586367},
                
                'D#/Eb Minor': {
                    'D#/Eb Minor Root Position': 515458,
                    'D#/Eb Minor 1st Inversion': 545863,
                    'D#/Eb Minor 2nd Inversion': 586366},

                'D#/Eb Diminished': {
                    'D#/Eb Diminished Root Position': 515457,
                    'D#/Eb Diminished 1st Inversion': 545763,
                    'D#/Eb Diminished 2nd Inversion': 545766},

                'D#/Eb Augmented': {
                    'D#/Eb Augmented Root Position': 515559,
                    'D#/Eb Augmented 1st Inversion': 555963,
                    'D#/Eb Augmented 2nd Inversion': 596367}
                },
            
            'E': 
                {'E Major': {
                    'E Major Root Position': 525659, 
                    'E Major 1st Inversion': 565964, 
                    'E Major 2nd Inversion': 596468},
                
                'E Minor': {
                    'E Minor Root Position': 525559,
                    'E Minor 1st Inversion': 555964,
                    'E Minor 2nd Inversion': 596467},

                'E Diminished': {
                    'E Diminished Root Position': 525558,
                    'E Diminished 1st Inversion': 555864,
                    'E Diminished 2nd Inversion': 586467},

                'E Augmented': {
                    'E Augmented Root Position': 525660,
                    'E Augmented 1st Inversion': 566064,
                    'E Augmented 2nd Inversion': 485256}
                },
            
            'F': 
                {'F Major': {
                    'F Major Root Position': 535760, 
                    'F Major 1st Inversion': 576065, 
                    'F Major 2nd Inversion': 485357},
                
                'F Minor': {
                    'F Minor Root Position': 535660,
                    'F Minor 1st Inversion': 566065,
                    'F Minor 2nd Inversion': 485356},

                'F Diminished': {
                    'F Diminished Root Position': 535659,
                    'F Diminished 1st Inversion': 565965,
                    'F Diminished 2nd Inversion': 596568},

                'F Augmented': {
                    'F Augmented Root Position': 535761,
                    'F Augmented 1st Inversion': 576165,
                    'F Augmented 2nd Inversion': 495357}
                },

            'F#/Gb': 
                {'F#/Gb Major': {
                    'F#/Gb Major Root Position': 545861, 
                    'F#/Gb Major 1st Inversion': 586166, 
                    'F#/Gb Major 2nd Inversion': 495458},
                
                'F#/Gb Minor': {
                    'F#/Gb Minor Root Position': 545761,
                    'F#/Gb Minor 1st Inversion': 576166,
                    'F#/Gb Minor 2nd Inversion': 495457},

                'F#/Gb Diminished': {
                    'F#/Gb Diminished Root Position': 545760,
                    'F#/Gb Diminished 1st Inversion': 576066,
                    'F#/Gb Diminished 2nd Inversion': 485760},

                'F#/Gb Augmented': {
                    'F#/Gb Augmented Root Position': 545862,
                    'F#/Gb Augmented 1st Inversion': 586266,
                    'F#/Gb Augmented 2nd Inversion': 505458}
                },

            'G': 
                {'G Major': {
                    'G Major Root Position': 555962, 
                    'G Major 1st Inversion': 596267, 
                    'G Major 2nd Inversion': 505559},
                
                'G Minor': {
                    'G Minor Root Position': 555862,
                    'G Minor 1st Inversion': 586267,
                    'G Minor 2nd Inversion': 505558},

                'G Diminished': {
                    'G Diminished Root Position': 555861,
                    'G Diminished 1st Inversion': 586167,
                    'G Diminished 2nd Inversion': 495558},

                'G Augmented': {
                    'G Augmented Root Position': 555963,
                    'G Augmented 1st Inversion': 596367,
                    'G Augmented 2nd Inversion': 515559}
                },
                
            'G#/Ab': 
                {'G#/Ab Major': {
                    'G#/Ab Major Root Position': 566063, 
                    'G#/Ab Major 1st Inversion': 485156, 
                    'G#/Ab Major 2nd Inversion': 515660},
                
                'G#/Ab Minor': {
                    'G#/Ab Minor Root Position': 565963,
                    'G#/Ab Minor 1st Inversion': 596268,
                    'G#/Ab Minor 2nd Inversion': 505659},

                'G#/Ab Diminished': {
                    'G#/Ab Diminished Root Position': 565962,
                    'G#/Ab Diminished 1st Inversion': 596268,
                    'G#/Ab Diminished 2nd Inversion': 505659},

                'G#/Ab Augmented': {
                    'G#/Ab Augmented Root Position': 566064,
                    'G#/Ab Augmented 1st Inversion': 485256,
                    'G#/Ab Augmented 2nd Inversion': 525660}
                },
            
            'A': 
                {'A Major': {
                    'A Major Root Position': 576164, 
                    'A Major 1st Inversion': 495257, 
                    'A Major 2nd Inversion': 525761},
                
                'A Minor': {
                    'A Minor Root Position': 576064,
                    'A Minor 1st Inversion': 485257,
                    'A Minor 2nd Inversion': 525760},

                'A Diminished': {
                    'A Diminished Root Position': 576063,
                    'A Diminished 1st Inversion': 485157,
                    'A Diminished 2nd Inversion': 515760},

                'A Augmented': {
                    'A Augmented Root Position': 576165,
                    'A Augmented 1st Inversion': 495357,
                    'A Augmented 2nd Inversion': 535761}
                },

            'A#/Bb': 
                {'A#/Bb Major': {
                    'A#/Bb Major Root Position': 586265, 
                    'A#/Bb Major 1st Inversion': 505358, 
                    'A#/Bb Major 2nd Inversion': 535862},
                
                'A#/Bb Minor': {
                    'A#/Bb Minor Root Position': 586165,
                    'A#/Bb Minor 1st Inversion': 495358,
                    'A#/Bb Minor 2nd Inversion': 525861},

                'A#/Bb Diminished': {
                    'A#/Bb Diminished Root Position': 586164,
                    'A#/Bb Diminished 1st Inversion': 495258,
                    'A#/Bb Diminished 2nd Inversion': 525861},

                'A#/Bb Augmented': {
                    'A#/Bb Augmented Root Position': 586266,
                    'A#/Bb Augmented 1st Inversion': 505458,
                    'A#/Bb Augmented 2nd Inversion': 545862}
                },

            'B': 
                {'B Major': {
                    'B Major Root Position': 596366, 
                    'B Major 1st Inversion': 515459, 
                    'B Major 2nd Inversion': 545963},
                
                'B Minor': {
                    'B Minor Root Position': 596266,
                    'B Minor 1st Inversion': 505459,
                    'B Minor 2nd Inversion': 545962},

                'B Diminished': {
                    'B Diminished Root Position': 596265,
                    'B Diminished 1st Inversion': 505359,
                    'B Diminished 2nd Inversion': 535962},

                'B Augmented': {
                    'B Augmented Root Position': 596367,
                    'B Augmented 1st Inversion': 515559,
                    'B Augmented 2nd Inversion': 559963}
                }
        }

# %%
numToName = {'C': 
                {'C Major': {
                    606467: 'C Major Root Position', 
                    646760: 'C Major 1st Inversion', 
                    676064: 'C Major 2nd Inversion'},
                
                'C Minor': {
                    606367: 'C Minor Root Position',
                    636760: 'C Minor 1st Inversion',
                    676063: 'C Minor 2nd Inversion'},

                'C Diminished': {
                    606366: 'C Diminished Root Position',
                    636660: 'C Diminished 1st Inversion',
                    666063: 'C Diminished 2nd Inversion'},

                'C Augmented': {
                    606468: 'C Augmented Root Position',
                    646860: 'C Augmented 1st Inversion',
                    686064: 'C Augmented 2nd Inversion'}
                },
            
            'C#/Db': 
                {'C#/Db Major': {
                    616568: 'C#/Db Major Root Position', 
                    656861: 'C#/Db Major 1st Inversion', 
                    686165: 'C#/Db Major 2nd Inversion'},
                
                'C#/Db Minor': {
                    616468: 'C#/Db Minor Root Position',
                    646861: 'C#/Db Minor 1st Inversion',
                    686164: 'C#/Db Minor 2nd Inversion'},

                'C#/Db Diminished': {
                    616467: 'C#/Db Diminished Root Position',
                    646761: 'C#/Db Diminished 1st Inversion',
                    676164: 'C#/Db Diminished 2nd Inversion'},

                'C#/Db Augmented': {
                    616569: 'C#/Db Augmented Root Position',
                    656961: 'C#/Db Augmented 1st Inversion',
                    696165: 'C#/Db Augmented 2nd Inversion'}
                },

            'D': 
                {'D Major': {
                    626669: 'D Major Root Position', 
                    666962: 'D Major 1st Inversion', 
                    696266: 'D Major 2nd Inversion'},
                
                'D Minor': {
                    626569: 'D Minor Root Position',
                    656962: 'D Minor 1st Inversion',
                    696265: 'D Minor 2nd Inversion'},

                'D Diminished': {
                    626568: 'D Diminished Root Position',
                    656862: 'D Diminished 1st Inversion',
                    686265: 'D Diminished 2nd Inversion'},

                'D Augmented': {
                    626670: 'D Augmented Root Position',
                    667062: 'D Augmented 1st Inversion',
                    706266: 'D Augmented 2nd Inversion'}
                },

            'D#/Eb': 
                {'D#/Eb Major': {
                    636770: 'D#/Eb Major Root Position', 
                    677063: 'D#/Eb Major 1st Inversion', 
                    706367: 'D#/Eb Major 2nd Inversion'},
                
                'D#/Eb Minor': {
                    636670: 'D#/Eb Minor Root Position',
                    667063: 'D#/Eb Minor 1st Inversion',
                    706366: 'D#/Eb Minor 2nd Inversion'},

                'D#/Eb Diminished': {
                    636669: 'D#/Eb Diminished Root Position',
                    666963: 'D#/Eb Diminished 1st Inversion',
                    696366: 'D#/Eb Diminished 2nd Inversion'},

                'D#/Eb Augmented': {
                    636771: 'D#/Eb Augmented Root Position',
                    677163: 'D#/Eb Augmented 1st Inversion',
                    716367: 'D#/Eb Augmented 2nd Inversion'}
                },
            
            'E': 
                {'E Major': {
                    646871: 'E Major Root Position', 
                    687164: 'E Major 1st Inversion', 
                    716468: 'E Major 2nd Inversion'},
                
                'E Minor': {
                    646771: 'E Minor Root Position',
                    677164: 'E Minor 1st Inversion',
                    716467: 'E Minor 2nd Inversion'},

                'E Diminished': {
                    646770: 'E Diminished Root Position',
                    677064: 'E Diminished 1st Inversion',
                    706467: 'E Diminished 2nd Inversion'},

                'E Augmented': {
                    646860: 'E Augmented Root Position',
                    686064: 'E Augmented 1st Inversion',
                    606468: 'E Augmented 2nd Inversion'}
                },
            
            'F': 
                {'F Major': {
                    656960: 'F Major Root Position', 
                    696065: 'F Major 1st Inversion', 
                    606569: 'F Major 2nd Inversion'},
                
                'F Minor': {
                    656860: 'F Minor Root Position',
                    686065: 'F Minor 1st Inversion',
                    606568: 'F Minor 2nd Inversion'},

                'F Diminished': {
                    656871: 'F Diminished Root Position',
                    687165: 'F Diminished 1st Inversion',
                    716568: 'F Diminished 2nd Inversion'},

                'F Augmented': {
                    656961: 'F Augmented Root Position',
                    696165: 'F Augmented 1st Inversion',
                    616569: 'F Augmented 2nd Inversion'}
                },

            'F#/Gb': 
                {'F#/Gb Major': {
                    667061: 'F#/Gb Major Root Position', 
                    706166: 'F#/Gb Major 1st Inversion', 
                    616670: 'F#/Gb Major 2nd Inversion'},
                
                'F#/Gb Minor': {
                    666961: 'F#/Gb Minor Root Position',
                    696166: 'F#/Gb Minor 1st Inversion',
                    616669: 'F#/Gb Minor 2nd Inversion'},

                'F#/Gb Diminished': {
                    666960: 'F#/Gb Diminished Root Position',
                    696066: 'F#/Gb Diminished 1st Inversion',
                    606669: 'F#/Gb Diminished 2nd Inversion'},

                'F#/Gb Augmented': {
                    667062: 'F#/Gb Augmented Root Position',
                    706266: 'F#/Gb Augmented 1st Inversion',
                    626670: 'F#/Gb Augmented 2nd Inversion'}
                },

            'G': 
                {'G Major': {
                    677162: 'G Major Root Position', 
                    716267: 'G Major 1st Inversion', 
                    626771: 'G Major 2nd Inversion'},
                
                'G Minor': {
                    677062: 'G Minor Root Position',
                    706267: 'G Minor 1st Inversion',
                    626770: 'G Minor 2nd Inversion'},

                'G Diminished': {
                    677061: 'G Diminished Root Position',
                    706167: 'G Diminished 1st Inversion',
                    616770: 'G Diminished 2nd Inversion'},

                'G Augmented': {
                    677163: 'G Augmented Root Position',
                    716367: 'G Augmented 1st Inversion',
                    636771: 'G Augmented 2nd Inversion'}
                },
                
            'G#/Ab': 
                {'G#/Ab Major': {
                    686063: 'G#/Ab Major Root Position', 
                    606368: 'G#/Ab Major 1st Inversion', 
                    636860: 'G#/Ab Major 2nd Inversion'},
                
                'G#/Ab Minor': {
                    687163: 'G#/Ab Minor Root Position',
                    716368: 'G#/Ab Minor 1st Inversion',
                    636871: 'G#/Ab Minor 2nd Inversion'},

                'G#/Ab Diminished': {
                    687162: 'G#/Ab Diminished Root Position',
                    716268: 'G#/Ab Diminished 1st Inversion',
                    626871: 'G#/Ab Diminished 2nd Inversion'},

                'G#/Ab Augmented': {
                    686064: 'G#/Ab Augmented Root Position',
                    606468: 'G#/Ab Augmented 1st Inversion',
                    646860: 'G#/Ab Augmented 2nd Inversion'}
                },
            
            'A': 
                {'A Major': {
                    696164: 'A Major Root Position', 
                    616469: 'A Major 1st Inversion', 
                    646961: 'A Major 2nd Inversion'},
                
                'A Minor': {
                    696064: 'A Minor Root Position',
                    606469: 'A Minor 1st Inversion',
                    646960: 'A Minor 2nd Inversion'},

                'A Diminished': {
                    696063: 'A Diminished Root Position',
                    606369: 'A Diminished 1st Inversion',
                    636960: 'A Diminished 2nd Inversion'},

                'A Augmented': {
                    696165: 'A Augmented Root Position',
                    616569: 'A Augmented 1st Inversion',
                    656961: 'A Augmented 2nd Inversion'}
                },

            'A#/Bb': 
                {'A#/Bb Major': {
                    706265: 'A#/Bb Major Root Position', 
                    626570: 'A#/Bb Major 1st Inversion', 
                    657062: 'A#/Bb Major 2nd Inversion'},
                
                'A#/Bb Minor': {
                    706165: 'A#/Bb Minor Root Position',
                    616570: 'A#/Bb Minor 1st Inversion',
                    657061: 'A#/Bb Minor 2nd Inversion'},

                'A#/Bb Diminished': {
                    706164: 'A#/Bb Diminished Root Position',
                    616470: 'A#/Bb Diminished 1st Inversion',
                    647061: 'A#/Bb Diminished 2nd Inversion'},

                'A#/Bb Augmented': {
                    706266: 'A#/Bb Augmented Root Position',
                    626670: 'A#/Bb Augmented 1st Inversion',
                    667062: 'A#/Bb Augmented 2nd Inversion'}
                },

            'B': 
                {'B Major': {
                    716366: 'B Major Root Position', 
                    636671: 'B Major 1st Inversion', 
                    667163: 'B Major 2nd Inversion'},
                
                'B Minor': {
                    716266: 'B Minor Root Position',
                    626671: 'B Minor 1st Inversion',
                    667162: 'B Minor 2nd Inversion'},

                'B Diminished': {
                    716265: 'B Diminished Root Position',
                    626571: 'B Diminished 1st Inversion',
                    657162: 'B Diminished 2nd Inversion'},

                'B Augmented': {
                    716367: 'B Augmented Root Position',
                    636771: 'B Augmented 1st Inversion',
                    677163: 'B Augmented 2nd Inversion'}
                }
        }

# %%
# Splits a 6 digit triad input input into individual note values
def chordIntSplit (chordInt, interval=2):
    chordInt = str(chordInt)
    split = []
    for k in range(0, len(chordInt), interval):
        split.append(int(chordInt[k:k + interval]))
    return split


# Reverses chordIntSplit, will combine the individual note values back into a single integer
def chordIntCombine (input):
    combine = int(str(int(input[0])) + str(int(input[1])) + str(int(input[2])))
    return combine

# %%
# Starting chord input: 
inputChord = 'C Major Root Position'
inputNum = nested_lookup(inputChord, nameToNum)
inputSplit = np.array(chordIntSplit(inputNum[0]))
# Print out MIDI numbers from user input
print(inputSplit)

destinationChord = 'F Augmented'
destinationNums = nested_lookup(key = destinationChord, document = nameToNum, wild = True, with_keys= False)


lookupArray = np.zeros(9)
magArray = np.zeros(9)
for n in range(0, len(destinationNums)-1):
    arrayIndex = n*3
    # Split destination chord into separate note values for comparison
    destTest = np.array(chordIntSplit(destinationNums[n+1]))
    lookupArray[arrayIndex] = chordIntCombine(destTest)
    magArray[arrayIndex] = np.sum(np.abs(destTest - inputSplit))
    #print(destTest)

    # Look at octave above and octave below
    upOct = destTest + 12
    lookupArray[arrayIndex+1] = chordIntCombine(upOct)
    magArray[arrayIndex+1] = np.sum(np.abs(upOct - inputSplit))
    #print(upOct)
    downOct = destTest - 12
    lookupArray[arrayIndex+2] = chordIntCombine(downOct)
    magArray[arrayIndex+2] = np.sum(np.abs(downOct - inputSplit))
    #print(downOct)
# Out:
# [48 52 55]

# %%
#print(lookupArray)
#print('----')
#print(magArray)
minVal = np.argmin(magArray)
destinationCalc = int(lookupArray[minVal])
splitStuff = np.array(chordIntSplit(destinationCalc))

normalize = (splitStuff%12) + 60

normalizeCombine = chordIntCombine(normalize)

print(splitStuff)
print(nested_lookup(normalizeCombine, numToName))
# Out:
# [49 53 57]
# ['C#/Db Augmented Root Position', 'F Augmented 2nd Inversion', 'A Augmented 1st Inversion']
